# %% [markdown]
# <a href="https://colab.research.google.com/github/Josemm17/Analitica-de-datos/blob/main/hola_mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#comentario de prueba
import numpy as np
from matplotlib import pyplot as plt

# %%
#definir dos arreglos de dimensión 100
ys=200+np.random.randn(100)
x=np.arange(0,100,1)

# %%
#graficar arreglos
plt.plot(x,ys, "-")
plt.fill_between(x, ys, 195, facecolor="r", alpha=0.6)
plt.title("Sample Visualization")
plt.xlabel("eje de las x", size=16)
plt.ylabel("eje de las y", size=16)
plt.show()
# Out:
# Text(0, 0.5, 'eje de las y')
